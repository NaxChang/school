# %%
# 比較運算子 bool
3 < 5 
3 == 3
3 !=3
# Out:
# False

# %%
# 判斷 if..else..
age = 19
if age < 18:
    print('未成年')
else:
    print("成年")
# Out:
# 成年

# %%
# list
student=['nameless',88,92,80]
print(student)
print(student[0])
print(student[1])
print(student[2])
print(student[3])
print(type(student))
# Out:
# ['nameless', 88, 92, 80]
# nameless
# 88
# 92
# 80
# <class 'list'>

# %%
student.append(92)
# Out:
# ['nameless', 88, 92, 80, 92, 92]

# %%
student.pop()
# Out:
# 92

# %%
student
# Out:
# ['nameless', 88, 92, 80, 92]

# %%
# dictionary 
# dict #key對應value
student_dict = {"name":'nameless',
 "chinese":87,
 "english":97,
 "math":86
 }
student_dict
print(type(student_dict))
# Out:
# <class 'dict'>

# %%
# subscript 沒有索引編號
student_dict["name"]
# Out:
# 'nameless'

# %%
student_dict.values()
# Out:
# dict_values(['nameless', 87, 97, 86])

# %%
student_dict.keys()
# 中括號 表示暫時的資料
# Out:
# dict_keys(['name', 'chinese', 'english', 'math'])

# %%
student_dict.pop('name')
# Out:
# 'nameless'

# %%
student_dict
# Out:
# {'chinese': 87, 'english': 97, 'math': 86}
